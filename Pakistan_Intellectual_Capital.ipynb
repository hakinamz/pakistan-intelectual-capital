# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9185588c-6a0e-46a9-b682-cf6868e04ff4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9185588c-6a0e-46a9-b682-cf6868e04ff4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Pakistan Intellectual Capital - Computer Science - Ver 1.csv to Pakistan Intellectual Capital - Computer Science - Ver 1.csv

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import sys
import warnings
warnings.filterwarnings("ignore") # For ingnoring warnings
np.set_printoptions(threshold=sys.maxsize)
pd.set_option('display.max_rows', None,'display.max_columns', None,'display.width', None,'display.max_colwidth', -1)
plt.rcParams["figure.figsize"] = (12,5)

# %%
df = pd.read_csv("Pakistan Intellectual Capital - Computer Science - Ver 1.csv", encoding='ISO-8859-1')
df.head()
# Out:
#    S#                Teacher Name University Currently Teaching  \
# 0  1   Dr. Ihsan Ullah             University of Balochistan
# 1  2   Dr. Atiq Ahmed              University of Balochistan
# 2  3   Dr. Abdul Basit             University of Balochistan
# 3  4   Mr. Muhammad Khalid Badini  University of Balochistan
# 4  5   Dr. Waheed Noor             University of Balochistan
#
#               Department Province University Located          Designation  \
# 0  Computer Science & IT  Balochistan                 Assistant Professor
# 1  Computer Science & IT  Balochistan                 Associate Professor
# 2  Computer Science & IT  Balochistan                 Assistant Professor
# 3  Computer Science & IT  Balochistan                 Assistant Professor
# 4  Computer Science & IT  Balochistan                 Assistant Professor
#
#   Terminal Degree                 Graduated from   Country  Year  \
# 0  PhD             NaN                            France   NaN
# 1  PhD             NaN                            France   NaN
# 2  PhD             Asian Institute of Technology  Thailand NaN
# 3  MS              NaN                            NaN      NaN
# 4  PhD             Asian Institute of Technology  Thailand NaN
#
#                            Area of Specialization/Research Interests  \
# 0  P2P Networks, Telecommunication Systems
# 1  Wireless Networks, Telecommunication Systems, Multi-agent Systems
# 2  Software Engineering & DBMS
# 3  Operating System & DBMS
# 4  DBMS
#
#   Other Information
# 0  NaN
# 1  NaN
# 2  NaN
# 3  On study leave
# 4  NaN

# %%
#Number of Professors per Department
df.Department.groupby(df.Department).count().sort_values(ascending=False).plot(kind="bar")

# %%
#Degree
df["Terminal Degree"].groupby(df["Terminal Degree"]).count().sort_values(ascending=False)[:30].plot(kind="bar")

# %%
#Specialization
df['Area of Specialization/Research Interests'].groupby(df["Area of Specialization/Research Interests"]).count().sort_values(ascending=False)[:20].plot(kind="bar")

# %%
#Country
df.Country.groupby(df.Country).count().sort_values(ascending=False)[1:20].plot(kind="bar")

# %%
#No. of Professors per Province
df["Province University Located"].groupby(df["Province University Located"]).count().sort_values(ascending=False).plot(kind="bar")
